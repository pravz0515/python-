# %%
l=[10,23,45,24,89]
mini=float("inf")
for num in l :
    if num < mini :
        mini=num
print(mini)
# Out:
# 10

# %%
l=[10,23,45,24,89]
maxi=float("-inf")
for num in l :
    if num > maxi :
        maxi=num
print(maxi)
# Out:
# 89
