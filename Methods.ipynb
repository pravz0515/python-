# %%
#create mobile class
class Mobile:
    company = 'Iphone' #class attribute
    def __init__(self, model, ram , rom, price):
        self.model = model     #instance attributes
        self.ram = ram         #instance attributes
        self.rom = rom         #instance attributes
        self.price = price     #instance attributes`
    def about_phone(self):
        return f"The {self.model} have {self.ram} GB RAM and {self.rom}GB ROM"
    def display():
        return "This is samsung company display"
    #class method
    @classmethod
    def  update_company(cls, new_name):
        cls.company = new_name
        return "Company name updated"
    #static method
    @staticmethod
    def charger_provide(cable = True):
        return "adapter + cable" if cable else "only adapter"
#object creation
iphone16 = Mobile("iphone 16", 16, 256, 2500000)
iphone17 = Mobile("iphone 17", 8, 256, 1500000)
print(iphone16.about_phone())
print(iphone16.update_company("Iphone pro"))
print(Mobile.charger_provide())
print(Mobile.company)
# Out:
# The iphone 16 have 16 GB RAM and 256GB ROM
# Company name updated
# adapter + cable
# Iphone pro

# %%
class Account:
    bank = "ICICI"
    def __init__ (self,username,balace,password):
        self.username = username
        self.balance = balance
        self.password = password
    def withdraw(self,amount):
        if self.balance >= amount:
            self.balance -= amount
            return f"{amount} withdrawal succesfully"
        return "Insufficient Balance"
    def depoiste(self, amount):
        self.balance += amount
        return f"{amount} Deposite successfully and current Balance is {self.balance}"
user = Account("pandu",50000,"pravz@gmail.com")
print(user.deposite(1000))
user.balance = 100000
print(user.withdraw(50000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 15
#      11         return "Insufficient Balance"
#      12     def depoiste(self, amount):
#      13         self.balance += amount
#      14         return f"{amount} Deposite successfully and current Balance is {self.balance}"
# ---> 15 user = Account("pandu",50000,"pravz@gmail.com")
#      16 print(user.deposite(1000))
#      17 user.balance = 100000
#      18 print(user.withdraw(50000))
#
# Cell In[15], line 5, in Account.__init__(self, username, balace, password)
#       3     def __init__ (self,username,balace,password):
#       4         self.username = username
# ----> 5         self.balance = balance
#       6         self.password = password
#
# NameError: name 'balance' is not defined

# %%
class Account:
    bank = "ICICI"

    def __init__(self, username, balance, password):
        self.username = username
        self.balance = balance
        self.password = password

    def withdraw(self, amount):
        if amount <= 0:
            return "Invalid withdrawal amount."

        if amount <= self.balance:
            self.balance -= amount
            return f"₹{amount} withdrawn successfully.\nCurrent Balance: ₹{self.balance}"
        else:
            return "Insufficient balance."

    def deposit(self, amount):
        if amount <= 0:
            return "Invalid deposit amount."

        self.balance += amount
        return f"₹{amount} deposited successfully.\nCurrent Balance: ₹{self.balance}"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 26
#      22
#      23         self.balance += amount
#      24         return f"₹{amount} deposited successfully.\nCurrent Balance: ₹{self.balance}"
#      25 user = Account("pandu",50000,"pravz@gmail.com")
# ---> 26 print(user.deposite(1000))
#      27 user.balance = 100000
#      28 print(user.withdraw(50000))
#
# AttributeError: 'Account' object has no attribute 'deposite'
