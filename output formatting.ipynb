# %%
#old formatting
name = "Ravi"
age = 20
print("My name "+ name +" and i m a "+ str(age) +" years old ")
# Out:
# My name Ravi and i m a 20 years old

# %%
name="Ravi"
age=20
marks=[85,98,65,67,78,99]
print("My name" , name , "and i am a" , age, "years old")
# Out:
# My name Ravi and i am a 20 years old

# %%
#Access Specifiers
#integer -%d
#float-%f
#string-%s
ame="Ravi"
age=20
marks=[85,98,65,67,78,99]
print("My name %s and i am a %d years old"%(name,age))
# Out:
# My name Ravi and i am a 20 years old

# %%
#Output Formatting
#Dot Format
name = "Ravi"
age = 20
marks = [67,34,5,6,778,00]
print("My name {} name and i am a {} years old".format(name, age))
print("My name {} name and i am a {} years old".format(age,name))
# Out:
# My name Ravi name and i am a 20 years old
# My name 20 name and i am a Ravi years old

# %%
#Output Formatting
#f- Format
name = "Ravi"
age = 20
marks = [67,34,5,6,778,00]
percentage = 98.7654
print(f"My name {name} name and i am a {age} years old and my percentage is {percentage}")
print(f"My name {name} name and i am a {age} years old and my percentage is {percentage:.2f}")
# Out:
# My name Ravi name and i am a 20 years old and my percentage is 98.7654
# My name Ravi name and i am a 20 years old and my percentage is 98.77

# %%
a=4
b=3
c=a+b
if (c==8) and (a==4) :
    print(True)
else :
    print(False)
# Out:
# False

# %%
n=int(input())
if n>=0 :
    print("positive")
else: 
    print("negative")
# Out:
#  66
# positive

# %%
n=int(input())
if n % 3== 0 :
    print("divisible by 3")
else: 
    print("not divisible by 3")
# Out:
#  33
# divisible by 3

# %%
n=int(input())
if n % 3== 0 and n % 5 == 0 :
    print("divisible by 3 and 5")
else: 

    print("not divisible by 3 and 5")
# Out:
#  45
# divisible by 3 and 5

# %%
#check num divide with 3 and 5
n=int(input())
if n % 3== 0 and n % 5 == 0 :
    print("divisible by 3 and 5")
else: 
    print("not divisible by 3 and 5")
# Out:
#  15
# divisible by 3 and 5

# %%
n=[1,23,4,5,6,7]
target=int(input())
if

# %%
#check num is perfect or not
num = int(input( ))

value = num ** 0.5

if value == int(value):
    print("Perfect square")
else:
    print("Not a perfect square")
# Out:
#  9
# Perfect square
